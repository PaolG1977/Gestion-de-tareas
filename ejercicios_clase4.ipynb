# %% [markdown]
# # Gestor de Tareas
#
# ## #Clase 4
#
# + Crear un programa en Python que permita gestionar tareas utilizando listas y diccionarios para almacenar y manipular los datos de las tareas. Además, practicaremos el uso de ramas en Git para organizar el desarrollo del proyecto

# %% [markdown]
# + Agregar al menos tres tareas distintas al programa utilizando el método insert() de la lista.
# Cada tarea debe ser representada como un diccionario con las claves nombre, descripcion y estado.

# %%
tareas_oficina = [{"Descargar Exptes": {"Descripción": "Analizar documentación", "Estado": "PENDIENTE"}},
                 {"Completar registro diario": {"Descripción": "Recopilar datos para seguimiento y respuestas", "Estado": "EN PROCESO"}},
                {"Organizar reunión con equipo informático": {"Descripción": "Enviar correo y agenda", "Estado": "COMPLETA"}}]

# %%
print(tareas_oficina [0])
# Out:
# {'Descargar Exptes': {'Descripción': 'Analizar documentación', 'Estado': 'PENDIENTE'}}

# %%
tareasoficina_extra= {"Redactar Notas" : {"Descripción": "Elaborar notas de pedido de insumos", "Estado": "EN PROCESO"}}

# %%
tareas_oficina.insert(1,tareasoficina_extra)

# %%
print (tareas_oficina)
# Out:
# [{'Descargar Exptes': {'Descripción': 'Analizar documentación', 'Estado': 'PENDIENTE'}}, {'Redactar Notas': {'Descripción': 'Elaborar notas de pedido de insumos', 'Estado': 'EN PROCESO'}}, {'Completar registro diario': {'Descripción': 'Recopilar datos para seguimiento y respuestas', 'Estado': 'EN PROCESO'}}, {'Organizar reunión con equipo informático': {'Descripción': 'Enviar correo y agenda', 'Estado': 'COMPLETA'}}]

# %%
tareas_oficina = [{"Tarea 1": "Descargar Exptes","Descripción": "Analizar documentación","Estado": "PENDIENTE"},
                {"Tarea 2": "Completar registro diario","Descripción": "Recopilar datos para seguimiento y respuestas",
                "Estado": "EN PROCESO"},
                {"Tarea 3": "Organizar reunión con equipo informático","Descripción": "Enviar correo y agenda",
                "Estado": "COMPLETA"}]

print(tareas_oficina[0])
# Out:
# {'Tarea 1': 'Descargar Exptes', 'Descripción': 'Analizar documentación', 'Estado': 'PENDIENTE'}

# %%
nueva_tarea = {"Tarea 4": "Revisar informe final","Descripción": "Verificar detalles y preparar presentación",
            "Estado": "PENDIENTE"
}

# %%
tareas_oficina.insert(1, nueva_tarea)

# %%
print(tareas_oficina)
# Out:
# [{'Tarea 1': 'Descargar Exptes', 'Descripción': 'Analizar documentación', 'Estado': 'PENDIENTE'}, {'Tarea 4': 'Revisar informe final', 'Descripción': 'Verificar detalles y preparar presentación', 'Estado': 'PENDIENTE'}, {'Tarea 2': 'Completar registro diario', 'Descripción': 'Recopilar datos para seguimiento y respuestas', 'Estado': 'EN PROCESO'}, {'Tarea 3': 'Organizar reunión con equipo informático', 'Descripción': 'Enviar correo y agenda', 'Estado': 'COMPLETA'}]

# %% [markdown]
# + Eliminación de Tareas:
# Utilizar el método pop() de la lista para eliminar una de las tareas ingresadas.

# %%
def eliminar_tarea(indice):
    if 0 <= indice < len(tareas_oficina):
        tarea_eliminada = tareas_oficina.pop(indice)
        print("Tarea eliminada: {tarea_eliminada}")

# %%
eliminar_tarea(1)
# Out:
# Tarea eliminada: {'Redactar Notas': {'Descripción': 'Elaborar notas de pedido de insumos', 'Estado': 'EN PROCESO'}}

# %% [markdown]
# +  Mostrar las Tareas:
# Imprimir en pantalla las tareas restantes almacenadas en la lista, accediendo directamente a los elementos mediante sus índices.

# %%
def mostrar_tareas():
    for tarea in tareas_oficina:
        print(tarea)

print("\nTareas restantes:")
mostrar_tareas()
# Out:
# Tareas restantes:
# {'Descargar Exptes': {'Descripción': 'Analizar documentación', 'Estado': 'PENDIENTE'}}
# {'Completar registro diario': {'Descripción': 'Recopilar datos para seguimiento y respuestas', 'Estado': 'EN PROCESO'}}
# {'Organizar reunión con equipo informático': {'Descripción': 'Enviar correo y agenda', 'Estado': 'COMPLETA'}}
